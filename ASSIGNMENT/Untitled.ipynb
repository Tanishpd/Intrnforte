# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Data Loading and Cleaning
# Load a sample dataset from Seaborn
df = sns.load_dataset('iris')

# Display the first few rows of the dataset
print("First few rows of the dataset:")
print(df.head())

# Check for missing values
print("\nMissing values in the dataset:")
print(df.isnull().sum())

# 2. Data Visualization and Inference

# 2.1. Pairplot for Exploring Relationships
# Pairplot to visualize relationships between numerical variables
sns.pairplot(df, hue='species', height=2.5)
plt.suptitle('Pairplot of Iris Dataset', y=1.02)
plt.show()

# Inference:
# - Sepal Length and Width: Setosa species generally has smaller sepal length and width compared to Versicolor and Virginica.
# - Petal Length and Width: Setosa species has smaller petal length and width compared to Versicolor and Virginica.
# - Relationships: There is a strong positive correlation between petal length and petal width.

# 2.2. Boxplot for Distribution and Outliers
# Boxplot to visualize distribution of sepal lengths by species
plt.figure(figsize=(8, 6))
sns.boxplot(x='species', y='sepal_length', data=df)
plt.title('Distribution of Sepal Lengths by Species')
plt.show()

# Inference:
# - Sepal Length: Virginica tends to have longer sepals compared to Setosa and Versicolor.
# - Outliers: There are some outliers in Setosa and Versicolor species.

# 2.3. Violin Plot for Distribution and KDE
# Violin plot to visualize distribution of petal lengths by species
plt.figure(figsize=(8, 6))
sns.violinplot(x='species', y='petal_length', data=df)
plt.title('Distribution of Petal Lengths by Species')
plt.show()

# Inference:
# - Petal Length: Setosa species generally has shorter petal lengths compared to Versicolor and Virginica.
# - Distribution: Setosa has a smaller range of petal lengths compared to Versicolor and Virginica.

# 2.4. Heatmap for Correlation Analysis
# Calculate the correlation matrix
corr = df.corr()

# Heatmap to visualize the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Iris Dataset')
plt.show()

# Inference:
# - Strong Correlations: Petal length and petal width have a strong positive correlation.
# - Weak Correlations: Sepal length and sepal width have a relatively weaker correlation.

# Conclusion:
# Data visualization allows us to explore and infer insights from data effectively. By using visualizations such as pairplots, 
# boxplots, violin plots, and heatmaps, we can gain a deeper understanding of relationships, distributions, and correlations 
# within the dataset. These inferences are essential for making informed decisions and further analysis in data science and 
# machine learning projects.
# Out:
# First few rows of the dataset:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#
# Missing values in the dataset:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Data Loading and Cleaning
# Load a sample dataset from Seaborn
df = sns.load_dataset('iris')

# Display the first few rows and summary statistics of the dataset
print("First few rows of the dataset:")
print(df.head())
print("\nSummary statistics:")
print(df.describe())

# Check for missing values
missing_values = df.isnull().sum()
print("\nMissing values in the dataset:")
print(missing_values)

# 2. Data Visualization and Inference

# 2.1. Pairplot for Exploring Relationships
# Pairplot to visualize relationships between numerical variables
plt.figure(figsize=(12, 8))
sns.pairplot(df, hue='species', height=2.5, palette='Set2')
plt.suptitle('Pairplot of Iris Dataset', y=1.02)
plt.show()

# Inference:
# - Sepal Length and Width: Setosa species generally have smaller sepal length and width compared to Versicolor and Virginica.
# - Petal Length and Width: Setosa species have smaller petal length and width compared to Versicolor and Virginica.
# - Relationships: There is a strong positive correlation between petal length and petal width across all species.

# 2.2. Boxplot for Distribution and Outliers
# Boxplot to visualize the distribution of sepal lengths by species
plt.figure(figsize=(10, 6))
sns.boxplot(x='species', y='sepal_length', data=df, palette='Set3')
plt.title('Distribution of Sepal Lengths by Species')
plt.xlabel('Species')
plt.ylabel('Sepal Length (cm)')
plt.show()

# Inference:
# - Sepal Length: Virginica tends to have longer sepals compared to Setosa and Versicolor.
# - Outliers: There are a few outliers in Setosa and Versicolor species, indicating some variability within these species.

# 2.3. Violin Plot for Distribution and KDE
# Violin plot to visualize the distribution of petal lengths by species
plt.figure(figsize=(10, 6))
sns.violinplot(x='species', y='petal_length', data=df, palette='Pastel1')
plt.title('Distribution of Petal Lengths by Species')
plt.xlabel('Species')
plt.ylabel('Petal Length (cm)')
plt.show()

# Inference:
# - Petal Length: Setosa species generally have shorter petal lengths compared to Versicolor and Virginica.
# - Distribution: Setosa has a narrower range of petal lengths, indicating less variation within this species compared to Versicolor and Virginica.

# 2.4. Heatmap for Correlation Analysis
# Calculate the correlation matrix
corr = df.corr()

# Heatmap to visualize the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5, square=True)
plt.title('Correlation Matrix of Iris Dataset')
plt.show()

# Inference:
# - Strong Correlations: Petal length and petal width have a strong positive correlation, which is consistent across species.
# - Weak Correlations: Sepal length and sepal width show a weaker correlation, suggesting these features vary more independently.

# Conclusion:
# Data visualization provides critical insights into the relationships, distributions, and correlations in the Iris dataset. 
# The visualizations demonstrate clear patterns that can guide further analysis, such as feature selection for predictive modeling.
# Out:
# First few rows of the dataset:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#
# Summary statistics:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# ...

# %%
df = sns.load_dataset('iris')

# %%
print(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
print(df.isnull().sum())
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
sns.pairplot(df, hue='species', height=2.5)
plt.suptitle('Pairplot of Iris Dataset', y=1.02)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='species', y='sepal_length', data=df)
plt.title('Distribution of Sepal Lengths by Species')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x='species', y='petal_length', data=df)
plt.title('Distribution of Petal Lengths by Species')
plt.show()

# %%
corr = df.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Iris Dataset')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 corr = df.corr()
#       2 plt.figure(figsize=(8, 6))
#       3 sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...

# %%
corr = df.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Iris Dataset')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 corr = df.corr()
#       2 plt.figure(figsize=(8, 6))
#       3 sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Data Loading and Cleaning
# Load a sample dataset from Seaborn
df = sns.load_dataset('iris')

# Display the first few rows of the dataset
print("First few rows of the dataset:")
print(df.head())

# Check for missing values
print("\nMissing values in the dataset:")
print(df.isnull().sum())

# 2. Data Visualization and Inference

# 2.1. Pairplot for Exploring Relationships
# Pairplot to visualize relationships between numerical variables
sns.pairplot(df, hue='species', height=2.5)
plt.suptitle('Pairplot of Iris Dataset', y=1.02)
plt.show()

# Inference:
# - Sepal Length and Width: Setosa species generally has smaller sepal length and width compared to Versicolor and Virginica.
# - Petal Length and Width: Setosa species has smaller petal length and width compared to Versicolor and Virginica.
# - Relationships: There is a strong positive correlation between petal length and petal width.

# 2.2. Boxplot for Distribution and Outliers
# Boxplot to visualize distribution of sepal lengths by species
plt.figure(figsize=(8, 6))
sns.boxplot(x='species', y='sepal_length', data=df)
plt.title('Distribution of Sepal Lengths by Species')
plt.show()

# Inference:
# - Sepal Length: Virginica tends to have longer sepals compared to Setosa and Versicolor.
# - Outliers: There are some outliers in Setosa and Versicolor species.

# 2.3. Violin Plot for Distribution and KDE
# Violin plot to visualize distribution of petal lengths by species
plt.figure(figsize=(8, 6))
sns.violinplot(x='species', y='petal_length', data=df)
plt.title('Distribution of Petal Lengths by Species')
plt.show()

# Inference:
# - Petal Length: Setosa species generally has shorter petal lengths compared to Versicolor and Virginica.
# - Distribution: Setosa has a smaller range of petal lengths compared to Versicolor and Virginica.

# 2.4. Heatmap for Correlation Analysis
# Calculate the correlation matrix
corr = df.corr()

# Heatmap to visualize the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Iris Dataset')
plt.show()

# Inference:
# - Strong Correlations: Petal length and petal width have a strong positive correlation.
# - Weak Correlations: Sepal length and sepal width have a relatively weaker correlation.

# Conclusion:
# Data visualization allows us to explore and infer insights from data effectively. By using visualizations such as pairplots, 
# boxplots, violin plots, and heatmaps, we can gain a deeper understanding of relationships, distributions, and correlations 
# within the dataset. These inferences are essential for making informed decisions and further analysis in data science and 
# machine learning projects.
# Out:
# First few rows of the dataset:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#
# Missing values in the dataset:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Iris dataset from Seaborn
df = sns.load_dataset('iris')

# Calculate the correlation matrix
corr = df.corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Iris Dataset')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 9
#       6 df = sns.load_dataset('iris')
#       8 # Calculate the correlation matrix
# ----> 9 corr = df.corr()
#      11 # Plot the heatmap
#      12 plt.figure(figsize=(8, 6))
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Iris dataset
df = sns.load_dataset('iris')

# Calculate the correlation matrix
corr = df.corr()

# Check the correlation matrix
print(corr)

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Iris Dataset')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 9
#       6 df = sns.load_dataset('iris')
#       8 # Calculate the correlation matrix
# ----> 9 corr = df.corr()
#      11 # Check the correlation matrix
#      12 print(corr)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Pairplot to visualize relationships between numerical variables
sns.pairplot(df, hue='species', height=2.5)
plt.suptitle('Pairplot of Iris Dataset', y=1.02)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
df['petal_area'] = df['petal_length'] * df['petal_width']

# %%
df['sepal_area'] = df['sepal_length'] * df['sepal_width']

# %%
df['petal_length_to_width_ratio'] = df['petal_length'] / df['petal_width']

# %%
df['sepal_length_to_width_ratio'] = df['sepal_length'] / df['sepal_width']

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# Load the Iris dataset
df = sns.load_dataset('iris')

# Define features and target variable
X = df.drop('species', axis=1)
y = df['species']

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Standardize the feature values
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Initialize Logistic Regression model
log_reg = LogisticRegression()

# Set up hyperparameter grid
log_reg_param_grid = {'C': [0.1, 1, 10], 'solver': ['liblinear', 'lbfgs']}

# Perform Grid Search with cross-validation
log_reg_cv = GridSearchCV(log_reg, log_reg_param_grid, cv=5)
log_reg_cv.fit(X_train, y_train)

# Best hyperparameters and accuracy
print("Best Hyperparameters for Logistic Regression:", log_reg_cv.best_params_)
log_reg_pred = log_reg_cv.predict(X_test)
print("Accuracy:", accuracy_score(y_test, log_reg_pred))
# Out:
# Best Hyperparameters for Logistic Regression: {'C': 1, 'solver': 'lbfgs'}
# Accuracy: 0.9111111111111111

# %%
# Initialize KNN model
knn = KNeighborsClassifier()

# Set up hyperparameter grid
knn_param_grid = {'n_neighbors': [3, 5, 7, 9], 'metric': ['euclidean', 'manhattan']}

# Perform Grid Search with cross-validation
knn_cv = GridSearchCV(knn, knn_param_grid, cv=5)
knn_cv.fit(X_train, y_train)

# Best hyperparameters and accuracy
print("Best Hyperparameters for KNN:", knn_cv.best_params_)
knn_pred = knn_cv.predict(X_test)
print("Accuracy:", accuracy_score(y_test, knn_pred))
# Out:
# Best Hyperparameters for KNN: {'metric': 'manhattan', 'n_neighbors': 5}
# Accuracy: 0.9111111111111111

# %%
# Initialize Decision Tree model
dtree = DecisionTreeClassifier()

# Set up hyperparameter grid
dtree_param_grid = {'max_depth': [3, 5, 7, None], 'min_samples_split': [2, 5, 10], 'criterion': ['gini', 'entropy']}

# Perform Grid Search with cross-validation
dtree_cv = GridSearchCV(dtree, dtree_param_grid, cv=5)
dtree_cv.fit(X_train, y_train)

# Best hyperparameters and accuracy
print("Best Hyperparameters for Decision Tree:", dtree_cv.best_params_)
dtree_pred = dtree_cv.predict(X_test)
print("Accuracy:", accuracy_score(y_test, dtree_pred))
# Out:
# Best Hyperparameters for Decision Tree: {'criterion': 'gini', 'max_depth': 3, 'min_samples_split': 2}
# Accuracy: 0.9777777777777777

# %%
# Initialize Random Forest model
rf = RandomForestClassifier()

# Set up hyperparameter grid
rf_param_grid = {'n_estimators': [50, 100, 200], 'max_features': ['auto', 'sqrt'], 'bootstrap': [True, False]}

# Perform Grid Search with cross-validation
rf_cv = GridSearchCV(rf, rf_param_grid, cv=5)
rf_cv.fit(X_train, y_train)

# Best hyperparameters and accuracy
print("Best Hyperparameters for Random Forest:", rf_cv.best_params_)
rf_pred = rf_cv.predict(X_test)
print("Accuracy:", accuracy_score(y_test, rf_pred))
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# ...

# %%
# Initialize SVM model
svm = SVC()

# Set up hyperparameter grid
svm_param_grid = {'C': [0.1, 1, 10], 'kernel': ['linear', 'rbf'], 'gamma': ['scale', 'auto']}

# Perform Grid Search with cross-validation
svm_cv = GridSearchCV(svm, svm_param_grid, cv=5)
svm_cv.fit(X_train, y_train)

# Best hyperparameters and accuracy
print("Best Hyperparameters for SVM:", svm_cv.best_params_)
svm_pred = svm_cv.predict(X_test)
print("Accuracy:", accuracy_score(y_test, svm_pred))
# Out:
# Best Hyperparameters for SVM: {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# Accuracy: 0.9111111111111111

# %%
# Evaluate and compare models
models = {
    'Logistic Regression': (log_reg_cv, log_reg_pred),
    'KNN': (knn_cv, knn_pred),
    'Decision Tree': (dtree_cv, dtree_pred),
    'Random Forest': (rf_cv, rf_pred),
    'SVM': (svm_cv, svm_pred)
}

for model_name, (model, pred) in models.items():
    print(f"\n{model_name}:\n")
    print(f"Best Parameters: {model.best_params_}")
    print(f"Accuracy: {accuracy_score(y_test, pred)}")
    print(f"Classification Report:\n{classification_report(y_test, pred)}")
    print(f"Confusion Matrix:\n{confusion_matrix(y_test, pred)}")
# Out:
# Logistic Regression:
#
# Best Parameters: {'C': 1, 'solver': 'lbfgs'}
# Accuracy: 0.9111111111111111
# Classification Report:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        15
#   versicolor       0.82      0.93      0.87        15
#    virginica       0.92      0.80      0.86        15
#
#     accuracy                           0.91        45
#    macro avg       0.92      0.91      0.91        45
# weighted avg       0.92      0.91      0.91        45
#
# Confusion Matrix:
# [[15  0  0]
#  [ 0 14  1]
#  [ 0  3 12]]
#
# KNN:
#
# Best Parameters: {'metric': 'manhattan', 'n_neighbors': 5}
# Accuracy: 0.9111111111111111
# Classification Report:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        15
#   versicolor       0.79      1.00      0.88        15
#    virginica       1.00      0.73      0.85        15
#
# ...

# %%
from sklearn.linear_model import LinearRegression

# Create a model instance
model = LinearRegression()

# Fit the model on training data
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       4 model = LinearRegression()
#       6 # Fit the model on training data
# ----> 7 model.fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined
